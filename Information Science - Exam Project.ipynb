# %%
import pandas as pd
import os
import csv
from csv import reader
import lxml.etree as ET
import sqlite3
import time

import urllib.parse
import urllib.request
import urllib.error

# %%
HPB = "https://sru.gbv.de/hpb?version=2.0&operation=searchRetrieve&query="
conn = sqlite3.connect(os.path.join('stcv.sqlite'))
c = conn.cursor()

# %%
query = """
SELECT DISTINCT
    title.cloi as identifier,
    COUNT(title.cloi) as id_count,
    author_vw as author_standardized,
    author_zvwr as author_original,
    author_zbd as author_dates,
    corporateauthor_nm as corporateauthor_standardized,
    corporateauthor_zvwr as corporateauthor_original,
    title_ti as title_title,
    title_lg as title_language,
    collation_fm as format,
    collation_ka as quires,
    collation_pg as pages,
    edition_ed as edition_info,
    impressum_ju1sv as year1,
    impressum_ju1ty as year1_type,
    impressum_ju2sv as year2,
    impressum_ju2ty as year2_type,
    impressum_pl as place,
    impressum_ug as printer,
    language_lg as language_info,
    number_nr as fingerprint
    FROM title
LEFT JOIN author on author.cloi = title.cloi
LEFT JOIN collation on collation.cloi = title.cloi
LEFT JOIN corporateauthor on corporateauthor.cloi = title.cloi
LEFT JOIN edition on edition.cloi = title.cloi
LEFT JOIN impressum on impressum.cloi = title.cloi
LEFT JOIN language on language.cloi = title.cloi
LEFT JOIN number on number.cloi = title.cloi
GROUP BY identifier
HAVING ID_COUNT=2
LIMIT 100
"""

# %%
c.execute(query)

data = [row for row in c.fetchall()]

FILENAME = "mycsvfile.csv"

with open(FILENAME, 'w', encoding="utf-8") as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerows(data)

conn.close()

# %%
df = pd.read_csv(FILENAME, header=None)

df.to_csv(FILENAME, header=["identifier", "id_count", "author_standardized", "author_original", "author_dates",
                                   "corporateauthor_standardized", "corporateauthor_original", "title_title", "title_language",
                                   "format", "quires", "pages", "edition_info", "year1", "year1_type", "year2", "year2_type",
                                   "place", "printer", "language_info", "fingerprint"], index=False)

# %%
def search_param(row: list):
    author = row[2]
    title = row[7]
    year = row[13]
    identifier = row[0]
    return author, title, year, identifier

    
def form_url(author, title, year):
    author = urllib.parse.quote(author)
    title = urllib.parse.quote(title)
    url = HPB + author + "%20\"" + title + "\"%20" + year + "&startRecord=1&maximumRecords=10"
    return url


def form_url_alt(title, year):
    title = urllib.parse.quote(title)
    url = HPB + "%20\"" + title + "\"%20" + year + "&startRecord=1&maximumRecords=10"
    return url


def query_HPB(search: str) -> bytes:
    try:
        with urllib.request.urlopen(url) as query:
            return query.read()
    except urllib.error.HTTPError as HTTPerr:
        exit(HTTPerr.code)
    except urllib.error.URLError as URLerr:
        exit(URLerr)      
        
        
def matcher(reply):
    tree = ET.ElementTree(ET.fromstring(reply, parser = ET.XMLParser()))
    root = tree.getroot()
    for elem in root.iter():
        if 'datafield' in elem.tag:
            if elem.attrib['tag'] == '035':
                grandchildren = elem.getchildren()
                for grandchild in grandchildren:
                    if grandchild.attrib['code'] == 'a':
                        return grandchild.text

# %%
with open(FILENAME, 'r', encoding="utf-8") as file:
    query_file = csv.reader(file)
    next(query_file, None)
    n = 1
    for row in query_file:
        url = form_url(search_param(row)[0], search_param(row)[1], search_param(row)[2])
        reply = query_HPB(url)
        hpb_id = matcher(reply)
        identifier = search_param(row)[3]
        try:
            print(str(n) + ". " + identifier + " matches " + hpb_id)
        except TypeError:
            print(str(n) + ". The primary search didn't yeild any results. Trying the alternative method...")
            url = form_url_alt(search_param(row)[1], search_param(row)[2])
            reply = query_HPB(url)
            hpb_id = matcher(reply)
            identifier = search_param(row)[3]
            print("   Secondary search results:\n    " + identifier + " matches " + hpb_id)
        n += 1
        time.sleep(4)
# Out:
# 1. c:stcv:12854444 matches BE-AnVE.c:stcv:12854444
# 2. c:stcv:12854501 matches BE-AnVE.c:stcv:12854501
# 3. c:stcv:12854549 matches BE-AnVE.c:stcv:12854549
# 4. c:stcv:12854587 matches BE-AnVE.c:stcv:12854587
# 5. c:stcv:12854599 matches BE-AnVE.c:stcv:12854599
# 6. c:stcv:12857052 matches BE-AnVE.c:stcv:12857052
# 7. c:stcv:12857069 matches BE-AnVE.c:stcv:12857069
# 8. c:stcv:12857131 matches BE-AnVE.c:stcv:12857131
# 9. c:stcv:12857158 matches BE-AnVE.c:stcv:12923714
# 10. c:stcv:12857275 matches BE-AnVE.c:stcv:12857275
# 11. c:stcv:12857374 matches BE-AnVE.c:stcv:12857374
# 12. c:stcv:12857912 matches BE-AnVE.c:stcv:12857912
# 13. c:stcv:12857923 matches BE-AnVE.c:stcv:12857923
# 14. c:stcv:12858124 matches BE-AnVE.c:stcv:12858124
# 15. c:stcv:12858392 matches BE-AnVE.c:stcv:12858392
# 16. c:stcv:12858408 matches BE-AnVE.c:stcv:12858408
# 17. c:stcv:12858413 matches BE-AnVE.c:stcv:12858413
# 18. c:stcv:12858468 matches BE-AnVE.c:stcv:12858468
# 19. c:stcv:12858494 matches BE-AnVE.c:stcv:12858509
# 20. c:stcv:12858622 matches BE-AnVE.c:stcv:12858622
# 21. c:stcv:12858690 matches BE-AnVE.c:stcv:12858690
# 22. c:stcv:12858729 matches BE-AnVE.c:stcv:12858729
# 23. c:stcv:12858795 matches BE-AnVE.c:stcv:12858795
# 24. c:stcv:12859250 matches BE-AnVE.c:stcv:12859250
# 25. c:stcv:12859427 matches BE-AnVE.c:stcv:12859427
# 26. c:stcv:12859712 matches BE-AnVE.c:stcv:12859712
# 27. c:stcv:12859754 matches BE-AnVE.c:stcv:12922627
# 28. c:stcv:12859820 matches BE-AnVE.c:stcv:12859820
# 29. c:stcv:12859871 matches BE-AnVE.c:stcv:7088533
# 30. c:stcv:12859905 matches BE-AnVE.c:stcv:12859905
# 31. c:stcv:12859931 matches BE-AnVE.c:stcv:12859931
# 32. c:stcv:12860028 matches BE-AnVE.c:stcv:12860028
# 33. c:stcv:12860136 matches BE-AnVE.c:stcv:12860136
# 34. c:stcv:12860498 matches BE-AnVE.c:stcv:12860498
# 35. c:stcv:12860697 matches BE-AnVE.c:stcv:12860697
# 36. c:stcv:12860711 matches BE-AnVE.c:stcv:12861813
# 37. c:stcv:12860736 matches BE-AnVE.c:stcv:12922627
# 38. c:stcv:12861541 matches BE-AnVE.c:stcv:12912294
# 39. c:stcv:12861606 matches BE-AnVE.c:stcv:12922627
# 40. c:stcv:12861734 matches BE-AnVE.c:stcv:12861760
# 41. c:stcv:12861760 matches BE-AnVE.c:stcv:12861760
# 42. c:stcv:12861798 matches BE-AnVE.c:stcv:12861798
# 43. c:stcv:12861813 matches BE-AnVE.c:stcv:12861813
# 44. c:stcv:12862032 matches BE-AnVE.c:stcv:12862032
# 45. c:stcv:12862035 matches BE-AnVE.c:stcv:12862035
# 46. c:stcv:12862038 matches BE-AnVE.c:stcv:12862038
# 47. c:stcv:12862053 matches BE-AnVE.c:stcv:12862053
# 48. c:stcv:12862058 matches BE-AnVE.c:stcv:12862058
# 49. c:stcv:12862118 matches US-icn.01.225593
# 50. c:stcv:12862125 matches BE-AnVE.c:stcv:12862125
# 51. c:stcv:12862153 matches BE-AnVE.c:stcv:12862153
# 52. c:stcv:12862168 matches BE-AnVE.c:stcv:12862168
# 53. c:stcv:12863004 matches BE-AnVE.c:stcv:12863004
# 54. c:stcv:12865436 matches BE-KBR00.CAT.1_1604019
# 55. c:stcv:12865677 matches BE-AnVE.c:stcv:12865677
# 56. c:stcv:12865828 matches BE-AnVE.c:stcv:12865828
# 57. c:stcv:12866841 matches BE-AnVE.c:stcv:12866841
# 58. c:stcv:12866854 matches (OCoLC)696380480
# 59. c:stcv:12866862 matches BE-AnVE.c:stcv:12866862
# 60. c:stcv:12866867 matches BE-AnVE.c:stcv:12866867
# 61. c:stcv:12866905 matches IT-ICCU.MUS0038800
# 62. c:stcv:12866912 matches US-mdbj.01.1464242
# 63. c:stcv:12866920 matches BE-KBR00.CAT.1_194739
# 64. c:stcv:12866939 matches BE-KBR00.CAT.1_410157
# 65. c:stcv:12867300 matches BE-AnVE.c:stcv:12867300
# 66. c:stcv:12867792 matches BE-AnVE.c:stcv:12867792
# 67. c:stcv:12867804 matches BE-AnVE.c:stcv:12867804
# 68. c:stcv:12867845 matches BE-AnVE.c:stcv:12867845
# 69. c:stcv:12867878 matches BE-AnVE.c:stcv:12867878
# 70. c:stcv:12867885 matches BE-AnVE.c:stcv:12867885
# 71. c:stcv:12867907 matches BE-AnVE.c:stcv:12867907
# 72. c:stcv:12867929 matches BE-AnVE.c:stcv:12867929
# 73. c:stcv:12867974 matches BE-AnVE.c:stcv:12867974
# 74. c:stcv:12868566 matches BE-AnVE.c:stcv:12868566
# 75. c:stcv:12868625 matches BE-AnVE.c:stcv:12868625
# 76. c:stcv:12868640 matches BE-AnVE.c:stcv:12868640
# 77. c:stcv:12868663 matches BE-AnVE.c:stcv:12868663
# 78. c:stcv:12868736 matches BE-AnVE.c:stcv:12868736
# 79. c:stcv:12868749 matches BE-AnVE.c:stcv:12868749
# 80. c:stcv:12868755 matches BE-AnVE.c:stcv:12868755
# 81. c:stcv:12868758 matches BE-AnVE.c:stcv:12868758
# 82. c:stcv:12868994 matches BE-AnVE.c:stcv:12911289
# 83. c:stcv:12869036 matches BE-AnVE.c:stcv:12869036
# 84. c:stcv:12869148 matches BE-AnVE.c:stcv:12869148
# 85. c:stcv:12869229 matches BE-AnVE.c:stcv:12869229
# 86. c:stcv:12869264 matches BE-AnVE.c:stcv:12920118
# 87. c:stcv:12869479 matches US-icn.01.365209
# 88. c:stcv:12869497 matches BE-AnVE.c:stcv:12869497
# 89. c:stcv:12869500 matches BE-AnVE.c:stcv:12869500
# 90. c:stcv:12869588 matches BE-KBR00.CAT.1_1780441
# 91. c:stcv:12869609 matches BE-AnVE.c:stcv:12869609
# 92. c:stcv:12869812 matches BE-AnVE.c:stcv:12869812
# 93. c:stcv:12869845 matches BE-AnVE.c:stcv:12869845
# 94. c:stcv:12869872 matches BE-AnVE.c:stcv:12869872
# 95. The primary search didn't yeild any results. Trying the alternative method...
#    Secondary search results:
#     c:stcv:12869899 matches BE-AnVE.c:stcv:12869899
# 96. c:stcv:12869970 matches BE-AnVE.c:stcv:12869970
# 97. c:stcv:12869997 matches BE-AnVE.c:stcv:3166791
# 98. c:stcv:12870045 matches BE-AnVE.c:stcv:12870045
# 99. c:stcv:12870054 matches BE-AnVE.c:stcv:12870054
# 100. c:stcv:12870121 matches BE-AnVE.c:stcv:12870121
